# %% [markdown]
# ## Access the S3 data directly without mounting the S3 bucket

# %%
access_key = dbutils.secrets.get(scope = "aws", key = "access-key")
secret_key = dbutils.secrets.get(scope = "aws", key = "secret-key")

sc._jsc.hadoopConfiguration().set("fs.s3a.access.key", access_key)
sc._jsc.hadoopConfiguration().set("fs.s3a.secret.key", secret_key)


df = spark.read.csv('s3://movie-dataset-youtube/movie_statistic_dataset.csv',inferSchema=True,header=True)
display(df)

# %% [markdown]
# #example

# %%
access_key = "AKIASOD6LQ5SL6CWFZQF"
secret_key = "RM/sh73a+5dJY5vEbCQz+EnRbFBGpsJrAb1Xv6iR"

sc._jsc.hadoopConfiguration().set("fs.s3a.access.key", access_key)
sc._jsc.hadoopConfiguration().set("fs.s3a.secret.key", secret_key)


df = spark.read.csv('s3://s3databricks2024samiro/all/',inferSchema=True,header=True)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>First Name</th><th>Last Name</th><th>Title</th><th>Company</th><th>Company Name for Emails</th><th>Email</th><th>Email Status</th><th>Email Confidence</th><th>Catch-all Status</th><th>Email Last Verified At</th><th>Seniority</th><th>Departments</th><th>Contact Owner</th><th>First Phone</th><th>Work Direct Phone</th><th>Home Phone</th><th>Mobile Phone</th><th>Corporate Phone</th><th>Other Phone</th><th>Stage</th><th>Lists</th><th>Last Contacted</th><th>Account Owner</th><th># Employees</th><th>Industry</th><th>Keywords</th><th>Person Linkedin Url</th><th>Website</th><th>Company Linkedin Url</th><th>Facebook Url</th><th>Twitter Url</th><th>City</th><th>State</th><th>Country</th><th>Company Address</th><th>Company City</th><th>Company State</th><th>Company Country</th><th>Company Phone</th><th>SEO Description</th><th>Technologies</th><th>Annual Revenue</th><th>Total Funding</th><th>Latest Funding</th><th>Latest Funding Amount</th><th>Last Raised At</th><th>Email Sent</th><th>Email Open</th><th>Email Bounced</th><th>Replied</th><th>Demoed</th><th>Number of Retail Locations</th><th>Apollo Contact Id</th><th>Apollo Account Id</th><th>User Managed</th></tr></thead><tbody><tr><td>Sam</td><td>Bradley</td><td>Environment Health Safety Lead</td><td>Worley</td><td>Worley</td><td>sam.bradley@worley.com</td><td>Verifying</td><td>null</td><td>Catch-all</td><td>null</td><td>Manager</td><td>Human Resources, Operations</td><td>ahmed.samir.mohamed@gmail.com</td><td>'+61 2 8923 6866</td><td>null</td><td>null</td><td>null</td><td>'+61 2 8923 6866</td><td>null</td><td>Cold</td><td>null</td><td>null</td><td>ahmed.samir.mohamed@gmail.com</td><td>51000</td><td>professional training & coaching</td><td>engineering, construction, minerals, metals, hydrocarbons, infrastructure, environment, power, procurement, project management, consulting, chemicals, resources, energy, new energy, renewables</td><td>http://www.linkedin.com/in/constructionindustry</td><td>http://www.worley.com</td><td>http://www.linkedin.com/company/worley</td><td>https://facebook.com/WorleyECR</td><td>https://twitter.com/Worley_ECR</td><td>Muscat</td><td>Muscat Governorate</td><td>Oman</td><td>141 Walker Street, North Sydney, New South Wales, Australia, 2060</td><td>North Sydney</td><td>New South Wales</td><td>Australia</td><td>'+61 2 8923 6866</td><td>We're a professional services company of energy, chemicals and resources experts helping customers shift their operations towards a more sustainable future.</td><td>Outlook, Microsoft Office 365, Microsoft Azure Hosting, NSOne, Gmail, Google Apps, Amazon AWS, Pardot, Salesforce, SOASTA, Google Maps, Linkedin Marketing Solutions, Google Places, Vimeo, Google Dynamic Remarketing, Disqus, Mobile Friendly, SiteCore, Google Tag Manager, Microsoft-IIS, iCIMS, Hotjar, ASP.NET, reCAPTCHA, CrazyEgg, Google Analytics, Google AdWords Conversion, Google Font API, DoubleClick Conversion, DoubleClick, React Native, , Reviews, SAP, Remote</td><td>7628000000</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>false</td><td>false</td><td>false</td><td>false</td><td>null</td><td>667d2800fce2350001655fd4</td><td>667d27a5cd0e3f000122ef76</td><td>false</td></tr><tr><td>Haitham</td><td>Said</td><td>Acting QHSSE Manager</td><td>Construction Development Company LLC (CDC)</td><td>Construction Development Company</td><td>haitham@cdc-qatar.com</td><td>Verifying</td><td>null</td><td>Catch-all</td><td>null</td><td>Manager</td><td>null</td><td>ahmed.samir.mohamed@gmail.com</td><td>'+974 4409 3444</td><td>null</td><td>null</td><td>null</td><td>'+974 4409 3444</td><td>null</td><td>Cold</td><td>null</td><td>null</td><td>ahmed.samir.mohamed@gmail.com</td><td>540</td><td>construction</td><td>construction, planning, consulting, permitting, design & engineering, procurement, commissioning, facility management</td><td>http://www.linkedin. ...

# %% [markdown]
# ## Access the S3 data by mounting the S3 bucket

# %%
access_key = dbutils.secrets.get(scope = "aws", key = "access-key")
secret_key = dbutils.secrets.get(scope = "aws", key = "secret-key")
encoded_secret_key = secret_key.replace("/", "%2F")

aws_bucket_name = "movie-dataset-youtube"
mount_name = "s3data"

dbutils.fs.mount(f"s3a://{access_key}:{encoded_secret_key}@{aws_bucket_name}", f"/mnt/{mount_name}")
display(dbutils.fs.ls(f"/mnt/{mount_name}"))

# %%
file_location = "dbfs:/mnt/s3data/movie_statistic_dataset.csv"

df = spark.read.csv(file_location, inferSchema = True, header= True)
display(df)

# %% [markdown]
# ## Unmount

# %%
dbutils.fs.unmount(f"/mnt/{mount_name}")

# %%
df = spark.read.csv(file_location, inferSchema = True, header= True)
display(df)
